# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# q1a:
# how many records are there, how many attributes, what kinds of attributes are there, ranges of values, distribution of values,relationships between attributes, missing values, and so on. A table is often a suitable
# way of showing such properties of a dataset. Notice if something is interesting (to you,
# or in general), make sure you write it down if you find something worth mentioning.
#
# • Make various plots of the data. Is there something interesting worth reporting? Report
# the figures, discuss what is in them. What meaning do those bars, lines, dots, etc.
# convey? Please select essential and interesting plots for discussion, as you have limited
# space for reporting your findings.

# %%
df = pd.read_csv('dataset_mood_smartphone.csv')

# %%
df
# Out:
#         Unnamed: 0       id                     time        variable   value
# 0                1  AS14.01  2014-02-26 13:00:00.000            mood   6.000
# 1                2  AS14.01  2014-02-26 15:00:00.000            mood   6.000
# 2                3  AS14.01  2014-02-26 18:00:00.000            mood   6.000
# 3                4  AS14.01  2014-02-26 21:00:00.000            mood   7.000
# 4                5  AS14.01  2014-02-27 09:00:00.000            mood   6.000
# ...            ...      ...                      ...             ...     ...
# 376907     2770399  AS14.30  2014-04-11 07:51:16.948  appCat.weather   8.032
# 376908     2772465  AS14.30  2014-04-19 11:00:32.747  appCat.weather   3.008
# 376909     2774026  AS14.30  2014-04-26 10:19:07.434  appCat.weather   7.026
# 376910     2774133  AS14.30  2014-04-27 00:44:48.450  appCat.weather  23.033
# 376911     2784435  AS14.32  2014-04-07 18:25:14.036  appCat.weather  22.431
#
# [376912 rows x 5 columns]

# %%
df.groupby('variable')['value'].describe()
# Out:
#                         count        mean         std        min       25%  \
# variable
# activity              22965.0    0.115958    0.186946      0.000   0.00000
# appCat.builtin        91288.0   18.538262  415.989243 -82798.871   2.02000
# appCat.communication  74276.0   43.343792  128.912750      0.006   5.21800
# appCat.entertainment  27125.0   37.576480  262.960476     -0.011   1.33400
# appCat.finance          939.0   21.755251   39.218361      0.131   4.07200
# appCat.game             813.0  128.391615  327.145246      1.003  14.14800
# appCat.office          5642.0   22.578892  449.601382      0.003   2.00400
# appCat.other           7650.0   25.810839  112.781355      0.014   7.01900
# appCat.social         19145.0   72.401906  261.551846      0.094   9.03000
# appCat.travel          2846.0   45.730850  246.109307      0.080   5.08650
# appCat.unknown          939.0   45.553006  119.400405      0.111   5.01800
# appCat.utilities       2487.0   18.537552   60.959134      0.246   3.15850
# appCat.weather          255.0   20.148714   24.943431      1.003   8.68400
# call                   5239.0    1.000000    0.000000      1.000   1.00000
# circumplex.arousal     5597.0   -0.098624    1.051868     -2.000  -1.00000
# circumplex.valence     5487.0    0.687808    0.671298     -2.000   0.00000
# mood                   5641.0    6.992555    1.032769      1.000   7.00000
# screen                96578.0   75.335206  253.822497      0.035   5.32225
# sms                    1798.0    1.000000    0.000000      1.000   1.00000
#
#                             50%         75%        max
# variable
# activity               0.021739    0.158333      1.000
# appCat.builtin         4.038000    9.922000  33960.246
# appCat.communication  16.225500   45.475750   9830.777
# appCat.entertainment   3.391000   14.922000  32148.677
# appCat.finance         8.026000   20.155000    355.513
# appCat.game           43.168000  123.625000   5491.793
# appCat.office          3.106000    8.043750  32708.818
# appCat.other          10.028000   16.829250   3892.038
# appCat.social         28.466000   75.372000  30000.906
# appCat.travel         18.144000   47.227250  10452.615
# appCat.unknown        17.190000   44.430500   2239.937
# appCat.utilities       8.030000   19.331000   1802.649
# appCat.weather        15.117000   25.349000    344.863
# call                   1.000000    1.000000      1.000
# circumplex.arousal     0.000000    1.000000      2.000
# circumplex.valence     1.000000    1.000000      2.000
# mood                   7.000000    8.000000     10.000
# screen                20.044500   62.540250   9867.007
# sms                    1.000000    1.000000      1.000

# %%
df.groupby('variable')['value'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='variable'>

# %%
df.boxplot(column='value', by='variable', rot=80)
# Out:
# <AxesSubplot:title={'center':'value'}, xlabel='variable'>

# %% [markdown]
# q1b.
#
# As the insights from Task 1A will have shown, the dataset you analyze contains quite some
# noise. Values are sometimes missing, and extreme or incorrect values are seen that are likely
# outliers youmay want to remove from the dataset. We will clean the dataset in two steps:
#
# • Apply an approach to remove extreme and incorrect values fromyour dataset. Describe
# what your approach is, why you consider that to be a good approach, and describe what
# the result of applying the approach is.
#
# • Impute the missing values using two different approaches. Describe the approaches
# and study the impact of applying them to your data. Argue which one of the two approacheswould
# be most suitable and select that one to form your cleaned dataset. Also
# base yourself on scientific literature for making your choice.
#
# Advanced: The advanced dataset contains a number of time series, select approaches to impute
# missing values that are logical for such time series. Also consider what to do with prolonged
# periods of missing data in a time series.

# %%
# done

# %% [markdown]
# # Q2A:
# Advanced: For the advanced assignment you go through the same steps (and shape it into
# a classification problem for predicting the mood of the next day), however you are required
# to use two different types of classification algorithms, namely one that uses the dataset you
# formed in Task 1C (e.g. using a random forest) and an algorithm that is inherently temporal
# (e.g. ARIMA, recurrent neural networks). Also consider a good evaluation setup given the
# nature of the dataset.

# %%
import pandas as pd

# Data Processing
import pandas as pd
import numpy as np

# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split, cross_val_score
from scipy.stats import randint

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image

# %%
# load datasets 
added_features = pd.read_csv('pre_processed_dataset/20230415_df_added_features.csv')
base_normalized = pd.read_csv('pre_processed_dataset/20230415_df_base_normalized.csv')
full_features = pd.read_csv('pre_processed_dataset/20230415_df_full_features.csv')

# %% [markdown]
# ## random forest

# %%
def create_dataset(data, drop, label_name, test_size=0.2):
    X = data.drop(drop, axis=1)
    y = data[label_name]
        
    return train_test_split(X, y, test_size=test_size)

# %%
X_train, X_test, y_train, y_test = create_dataset(base_normalized, ['id', 'time', 'day_id', 'mood', 'label'], 'label')

# %%
def train_rf(xtrain, xtest, ytrain, ytest, max_depth=None, n_estimators=100, random_search=False, cross_validation=False, epochs=10):
    avg = 0
    
    if random_search: 
        
        rf = RandomForestClassifier()

        param_dist = {'n_estimators': randint(100,200),
          'max_depth': randint(5,15)}

        rand_search = RandomizedSearchCV(rf, 
                             param_distributions = param_dist, 
                             n_iter=50, 
                             cv=5)

        rand_search.fit(xtrain, ytrain)
        
        rf = rand_search.best_estimator_
        print('Best hyperparameters:',  rand_search.best_params_)
    
    else: 
         rf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
    
    for e in range(epochs):
        if cross_validation:
            avg += np.mean(cross_val_score(rf, xtrain, ytrain, cv=5))
        else: 
            rf.fit(xtrain, ytrain)
            avg += rf.score(xtest, ytest)
    
    # returns averaged score and last model
    return avg / epochs, rf

# %%
# no randomized search, no crossvalidation
train_rf(X_train, X_test, y_train, y_test)
# Out:
# (0.6104651162790699, RandomForestClassifier())

# %%
# with cross-validation
train_rf(X_train, X_test, y_train, y_test, cross_validation=True)
# Out:
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# (0.5934186951831528, RandomForestClassifier())

# %%
# with randomized search + cross validation
train_rf(X_train, X_test, y_train, y_test, random_search=True)
# Out:
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Best hyperparameters: {'max_depth': 13, 'n_estimators': 107}
# (0.6112403100775194, RandomForestClassifier(max_depth=13, n_estimators=107))

# %% [markdown]
# ## with feature engineering

# %%
added_features
# Out:
#            id        time  day_id  is_weekday  mood  label  \
# 0     AS14.01  2014-03-21    33.0           1  6.20    6.0
# 1     AS14.01  2014-03-22    34.0           0  6.40    6.0
# 2     AS14.01  2014-03-23    35.0           0  6.80    7.0
# 3     AS14.01  2014-03-24    36.0           1  6.00    6.0
# 4     AS14.01  2014-03-25    37.0           1  6.75    7.0
# ...       ...         ...     ...         ...   ...    ...
# 1285  AS14.33  2014-05-27   100.0           1  6.20    6.0
# 1286  AS14.33  2014-05-28   101.0           1  8.20    8.0
# 1287  AS14.33  2014-05-29   102.0           1  7.00    7.0
# 1288  AS14.33  2014-05-30   103.0           1  6.80    7.0
# 1289  AS14.33  2014-05-31   104.0           0  7.00    7.0
#
#       mood_5_day_average  circumplex.arousal_5_day_average  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
# ...                  ...                               ...
# 1285            0.027397                          0.420886
# 1286            0.080235                          0.212025
# 1287            0.358121                          0.370253
# 1288            0.428571                          0.259494
# 1289            0.493151                          0.250000
#
#       circumplex.valence_5_day_average  activity_5_day_average  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4                                  NaN                     NaN
# ...                                ...                     ...
# 1285                          0.084249                0.221601
# 1286                          0.117216                0.222638
# 1287                          0.380952                0.296221
# 1288                          0.545788                0.434169
# 1289                          0.384615                0.462130
#
#       screen_5_day_average  call_5_day_average  sms_5_day_average  \
# 0                      NaN                 NaN                NaN
# 1                      NaN                 NaN                NaN
# 2                      NaN                 NaN                NaN
# 3                      NaN                 NaN                NaN
# 4                      NaN                 NaN                NaN
# ...                    ...                 ...                ...
# 1285              0.443784                0.75                0.6
# 1286              0.446881                0.75                0.8
# 1287              0.364760                0.75                0.8
# 1288              0.323200                1.00                1.0
# 1289              0.328320                1.00                0.8
#
#       new_appCat.work_5_day_average  new_appCat.recreation_5_day_average  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
# ...                             ...                                  ...
# 1285                       0.396999                             0.703891
# 1286                       0.635194                             0.650200
# 1287                       0.756796                             0.237755
# 1288                       0.878398                             0.213920
# 1289                       1.000000                             0.160706
#
#       new_appCat.connection_5_day_average  new_appCat.utils_5_day_average  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 1285                             0.477075                        0.187801
# 1286                             0.500108                        0.206250
# 1287                             0.315715                        0.171673
# 1288                             0.515160                        0.109292
# 1289                             0.594817                        0.207422
#
#       new_appCat.others_5_day_average  most_used_app
# 0                                 NaN       0.076786
# 1                                 NaN       0.004762
# 2                                 NaN       0.033967
# 3                                 NaN       0.178745
# 4                                 NaN       0.075559
# ...                               ...            ...
# 1285                         0.151237       0.276812
# 1286                         0.158814       0.221570
# 1287                         0.249468       0.566145
# 1288                         0.228728       0.166457
# 1289                         0.230608       0.166457
#
# [1290 rows x 19 columns]

# %%
X_train, X_test, y_train, y_test = create_dataset(added_features.dropna(), ['label', 'id', 'time', 'mood'], 'label')

# %%
# added features
train_rf(X_train, X_test, y_train, y_test)
# Out:
# (0.5943722943722943, RandomForestClassifier())

# %%
# with cross-validation
train_rf(X_train, X_test, y_train, y_test, cross_validation=True)
# Out:
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# (0.5596269095182139, RandomForestClassifier())

# %%
# with random search and cross validation
train_rf(X_train, X_test, y_train, y_test, random_search=True)
# Out:
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Best hyperparameters: {'max_depth': 13, 'n_estimators': 147}
# (0.5181818181818182, RandomForestClassifier(max_depth=13, n_estimators=147))

# %% [markdown]
# ## full features (engineered + original)

# %%
full_features
# Out:
#            id        time  day_id  is_weekday  mood  label  \
# 0     AS14.01  2014-03-21    33.0           1  6.20    6.0
# 1     AS14.01  2014-03-22    34.0           0  6.40    6.0
# 2     AS14.01  2014-03-23    35.0           0  6.80    7.0
# 3     AS14.01  2014-03-24    36.0           1  6.00    6.0
# 4     AS14.01  2014-03-25    37.0           1  6.75    7.0
# ...       ...         ...     ...         ...   ...    ...
# 1285  AS14.33  2014-05-27   100.0           1  6.20    6.0
# 1286  AS14.33  2014-05-28   101.0           1  8.20    8.0
# 1287  AS14.33  2014-05-29   102.0           1  7.00    7.0
# 1288  AS14.33  2014-05-30   103.0           1  6.80    7.0
# 1289  AS14.33  2014-05-31   104.0           0  7.00    7.0
#
#       circumplex.arousal  circumplex.valence  activity    screen  ...  \
# 0               0.707317                 0.2  0.538586  0.523964  ...
# 1               0.902439                 0.5  1.000000  0.000000  ...
# 2               0.707317                 0.8  0.577584  0.096115  ...
# 3               1.000000                 0.0  0.291394  0.144061  ...
# 4               0.853659                 0.5  0.378503  0.600205  ...
# ...                  ...                 ...       ...       ...  ...
# 1285            0.500000                 0.5  0.032044  0.163786  ...
# 1286            0.714286                 0.9  0.297294  0.163890  ...
# 1287            0.238095                 0.8  0.490686  0.174908  ...
# 1288            0.428571                 0.1  0.559626  0.107321  ...
# 1289            0.000000                 0.8  0.559626  0.107321  ...
#
#       activity_5_day_average  screen_5_day_average  call_5_day_average  \
# 0                        NaN                   NaN                 NaN
# 1                        NaN                   NaN                 NaN
# 2                        NaN                   NaN                 NaN
# 3                        NaN                   NaN                 NaN
# 4                        NaN                   NaN                 NaN
# ...                      ...                   ...                 ...
# 1285                0.221601              0.443784                0.75
# 1286                0.222638              0.446881                0.75
# 1287                0.296221              0.364760                0.75
# 1288                0.434169              0.323200                1.00
# 1289                0.462130              0.328320                1.00
#
#       sms_5_day_average  new_appCat.work_5_day_average  \
# 0                   NaN                            NaN
# 1                   NaN                            NaN
# 2                   NaN                            NaN
# 3                   NaN                            NaN
# 4                   NaN                            NaN
# ...                 ...                            ...
# 1285                0.6                       0.396999
# 1286                0.8                       0.635194
# 1287                0.8                       0.756796
# 1288                1.0                       0.878398
# 1289                0.8                       1.000000
#
#       new_appCat.recreation_5_day_average  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 1285                             0.703891
# 1286                             0.650200
# 1287                             0.237755
# 1288                             0.213920
# 1289                             0.160706
#
#       new_appCat.connection_5_day_average  new_appCat.utils_5_day_average  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 1285                             0.477075                        0.187801
# 1286                             0.500108                        0.206250
# 1287                             0.315715                        0.171673
# 1288                             0.515160                        0.109292
# 1289                             0.594817                        0.207422
#
#       new_appCat.others_5_day_average  most_used_app
# 0                                 NaN       0.076786
# 1                                 NaN       0.004762
# 2                                 NaN       0.033967
# 3                                 NaN       0.178745
# 4                                 NaN       0.075559
# ...                               ...            ...
# 1285                         0.151237       0.276812
# 1286                         0.158814       0.221570
# 1287                         0.249468       0.566145
# 1288                         0.228728       0.166457
# 1289                         0.230608       0.166457
#
# [1290 rows x 42 columns]

# %%
X_train, X_test, y_train, y_test = create_dataset(full_features.dropna(), ['label', 'id', 'time', 'mood'], 'label')
train_rf(X_train, X_test, y_train, y_test, random_search=True)
# Out:
# accuracy at epoch 0: 0.6071428571428571
# accuracy at epoch 1: 0.5714285714285714
# accuracy at epoch 2: 0.6785714285714286
# accuracy at epoch 3: 0.6071428571428571
# accuracy at epoch 4: 0.5714285714285714
# accuracy at epoch 5: 0.6428571428571429
# accuracy at epoch 6: 0.6071428571428571
# accuracy at epoch 7: 0.5714285714285714
# accuracy at epoch 8: 0.5357142857142857
# accuracy at epoch 9: 0.6071428571428571
# Best hyperparameters: {'max_depth': 9, 'n_estimators': 316}
# accuracy of best model: 0.6071428571428571
# 0.5999999999999999

# %% [markdown]
# ## earlier datasets

# %%
without_normalization['label'] = without_normalization['mood'].round()

# %%
without_normalization
# Out:
#            id  day_id        date  mood  mood_5_day_average  \
# 0     AS14.01     1.0  2014-02-17   0.0                 NaN
# 1     AS14.01     2.0  2014-02-18   0.0                 NaN
# 2     AS14.01     3.0  2014-02-19   0.0                 NaN
# 3     AS14.01     4.0  2014-02-20   0.0                 NaN
# 4     AS14.01     5.0  2014-02-21   0.0                 NaN
# ...       ...     ...         ...   ...                 ...
# 2220  AS14.33   100.0  2014-05-27   6.2            5.926667
# 2221  AS14.33   101.0  2014-05-28   8.2            6.016667
# 2222  AS14.33   102.0  2014-05-29   7.0            6.490000
# 2223  AS14.33   103.0  2014-05-30   6.8            6.610000
# 2224  AS14.33   104.0  2014-05-31   7.0            6.720000
#
#       circumplex.arousal_5_day_average  circumplex.valence_5_day_average  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 2220                         -0.446667                          0.166667
# 2221                         -0.666667                          0.196667
# 2222                         -0.500000                          0.436667
# 2223                         -0.616667                          0.586667
# 2224                         -0.626667                          0.440000
#
#       activity_5_day_average  screen_5_day_average  call_5_day_average  \
# 0                        NaN                   NaN                 NaN
# 1                        NaN                   NaN                 NaN
# 2                        NaN                   NaN                 NaN
# 3                        NaN                   NaN                 NaN
# 4                        NaN                   NaN                 NaN
# ...                      ...                   ...                 ...
# 2220                0.064616            168.063380                 0.8
# 2221                0.064850            168.639195                 0.8
# 2222                0.081393            153.371737                 0.8
# 2223                0.112406            145.645288                 1.0
# 2224                0.118693            146.597104                 1.0
#
#       sms_5_day_average  appCat.work_5_day_average  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                   NaN                        NaN
# ...                 ...                        ...
# 2220                0.6                  26.106000
# 2221                0.8                  26.106000
# 2222                0.8                  35.053725
# 2223                1.0                  35.053725
# 2224                0.8                  35.053725
#
#       appCat.recreation_5_day_average  appCat.utils_5_day_average  \
# 0                                 NaN                         NaN
# 1                                 NaN                         NaN
# 2                                 NaN                         NaN
# 3                                 NaN                         NaN
# 4                                 NaN                         NaN
# ...                               ...                         ...
# 2220                       253.477400                   14.400107
# 2221                       250.311496                   17.185163
# 2222                       188.398839                   17.844870
# 2223                       206.680193                   17.358841
# 2224                       209.455045                   25.313314
#
#       appCat.convenience_5_day_average  label
# 0                                  NaN    0.0
# 1                                  NaN    0.0
# 2                                  NaN    0.0
# 3                                  NaN    0.0
# 4                                  NaN    0.0
# ...                                ...    ...
# 2220                         14.543852    6.0
# 2221                         14.694802    8.0
# 2222                         17.247096    7.0
# 2223                         16.579529    7.0
# 2224                         17.103962    7.0
#
# [2225 rows x 16 columns]

# %%
X_train, X_test, y_train, y_test = create_dataset(without_normalization.dropna(), ['label', 'id', 'day_id', 'date', 'mood'], 'label')
train_rf(X_train, X_test, y_train, y_test, random_search=True)
# Out:
# accuracy at epoch 0: 0.6961722488038278
# accuracy at epoch 1: 0.6818181818181818
# accuracy at epoch 2: 0.7033492822966507
# accuracy at epoch 3: 0.6866028708133971
# accuracy at epoch 4: 0.6961722488038278
# accuracy at epoch 5: 0.6650717703349283
# accuracy at epoch 6: 0.6961722488038278
# accuracy at epoch 7: 0.6794258373205742
# accuracy at epoch 8: 0.6913875598086124
# accuracy at epoch 9: 0.6794258373205742
# /home/dariusbarsony/anaconda3/envs/cue/lib/python3.9/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Best hyperparameters: {'max_depth': 9, 'n_estimators': 438}
# accuracy of best model: 0.6866028708133971
# 0.6875598086124401

# %% [markdown]
# ## ARIMA

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm

# %%
added_features = pd.read_csv('pre_processed_dataset/20230415_df_base_normalized.csv', index_col='time')

# %% [markdown]
# ## data analysis

# %%
added_features.index = pd.DatetimeIndex(added_features.index)
added_features
# Out:
#                  id  day_id  mood  label  circumplex.arousal  \
# time
# 2014-03-27  AS14.01    39.0   7.0    7.0            0.707317
# 2014-03-28  AS14.01    40.0   6.4    6.0            0.317073
# 2014-03-29  AS14.01    41.0   8.0    8.0            0.707317
# 2014-03-30  AS14.01    42.0   7.5    8.0            0.365854
# 2014-03-31  AS14.01    43.0   7.4    7.0            0.609756
# ...             ...     ...   ...    ...                 ...
# 2014-05-27  AS14.33   100.0   6.2    6.0            0.500000
# 2014-05-28  AS14.33   101.0   8.2    8.0            0.714286
# 2014-05-29  AS14.33   102.0   7.0    7.0            0.238095
# 2014-05-30  AS14.33   103.0   6.8    7.0            0.428571
# 2014-05-31  AS14.33   104.0   7.0    7.0            0.000000
#
#             circumplex.valence  activity    screen  call  sms  ...  \
# time                                                           ...
# 2014-03-27                0.80  0.652832  0.403093   1.0  1.0  ...
# 2014-03-28                0.60  0.366495  0.041181   1.0  0.0  ...
# 2014-03-29                1.00  0.243120  0.407242   1.0  1.0  ...
# 2014-03-30                0.75  0.157372  0.592444   0.0  0.0  ...
# 2014-03-31                0.60  0.253453  0.236383   1.0  0.0  ...
# ...                        ...       ...       ...   ...  ...  ...
# 2014-05-27                0.50  0.032044  0.163786   1.0  1.0  ...
# 2014-05-28                0.90  0.297294  0.163890   1.0  1.0  ...
# 2014-05-29                0.80  0.490686  0.174908   1.0  1.0  ...
# 2014-05-30                0.10  0.559626  0.107321   1.0  0.0  ...
# 2014-05-31                0.80  0.559626  0.107321   0.0  0.0  ...
#
#             appCat.finance  appCat.game  appCat.office  appCat.other  \
# time
# 2014-03-27        0.167228     0.697244       0.139409      0.034808
# 2014-03-28        0.144273     0.697244       0.175059      0.315603
# 2014-03-29        0.110673     0.565713       0.210709      0.180446
# 2014-03-30        0.077072     0.434182       0.246359      0.060756
# 2014-03-31        0.043472     0.302651       0.282009      0.182321
# ...                    ...          ...            ...           ...
# 2014-05-27        0.000000     0.000000       0.500000      0.249610
# 2014-05-28        0.000000     0.000000       0.000000      0.492745
# 2014-05-29        0.000000     0.000000       0.000000      0.053728
# 2014-05-30        0.000000     0.000000       0.000000      0.072780
# 2014-05-31        0.000000     0.000000       0.000000      0.072780
#
#             appCat.social  appCat.travel  appCat.unknown  appCat.utilities  \
# time
# 2014-03-27       0.079591       0.134387        0.923518          0.097642
# 2014-03-28       0.020178       0.393947        0.949012          0.224053
# 2014-03-29       0.063118       0.089808        0.974506          0.177249
# 2014-03-30       0.058992       0.159064        1.000000          0.297957
# 2014-03-31       0.059483       0.228320        0.868779          0.062125
# ...                   ...            ...             ...               ...
# 2014-05-27       0.106205       0.053341        0.019081          0.842115
# 2014-05-28       0.363026       0.032430        0.021790          0.172678
# 2014-05-29       0.884805       0.011519        0.024499          0.000000
# 2014-05-30       0.237865       0.503052        0.027207          0.684624
# 2014-05-31       0.237865       0.503052        0.027207          0.684624
#
#             appCat.weather  first_difference
# time
# 2014-03-27             0.0               0.0
# 2014-03-28             0.0              -1.0
# 2014-03-29             0.0               2.0
# 2014-03-30             0.0               0.0
# 2014-03-31             0.0              -1.0
# ...                    ...               ...
# 2014-05-27             0.0               1.0
# 2014-05-28             0.0               2.0
# 2014-05-29             0.0              -1.0
# 2014-05-30             0.0               0.0
# 2014-05-31             0.0               0.0
#
# [1284 rows x 23 columns]

# %%
# plot the data
added_features.label.iloc[:100].plot(figsize=(12,8), title= 'mood of patients', fontsize=14)
# Out:
# <AxesSubplot:title={'center':'mood of patients'}, xlabel='time'>

# %%
added_features.label
# Out:
# time
# 2014-03-27    7.0
# 2014-03-28    6.0
# 2014-03-29    8.0
# 2014-03-30    8.0
# 2014-03-31    7.0
#              ...
# 2014-05-27    6.0
# 2014-05-28    8.0
# 2014-05-29    7.0
# 2014-05-30    7.0
# 2014-05-31    7.0
# Name: label, Length: 1284, dtype: float64

# %%
decomposition = seasonal_decompose(added_features.label, period=30)  
fig = plt.figure()  
fig = decomposition.plot()  
fig.set_size_inches(15, 8)

# %%
trend = decomposition.trend
seasonal = decomposition.seasonal 
residual = decomposition.resid

trend, seasonal, residual
# Out:
# (time
#  2014-03-27   NaN
#  2014-03-28   NaN
#  2014-03-29   NaN
#  2014-03-30   NaN
#  2014-03-31   NaN
#                ..
#  2014-05-27   NaN
#  2014-05-28   NaN
#  2014-05-29   NaN
#  2014-05-30   NaN
#  2014-05-31   NaN
#  Name: trend, Length: 1284, dtype: float64,
#  time
#  2014-03-27   -0.106391
#  2014-03-28   -0.200835
#  2014-03-29   -0.009169
#  2014-03-30    0.040038
#  2014-03-31    0.040831
#                  ...
#  2014-05-27   -0.061946
#  2014-05-28    0.105514
#  2014-05-29    0.057895
#  2014-05-30    0.057498
#  2014-05-31    0.176149
#  Name: seasonal, Length: 1284, dtype: float64,
#  time
#  2014-03-27   NaN
#  2014-03-28   NaN
#  2014-03-29   NaN
#  2014-03-30   NaN
#  2014-03-31   NaN
#                ..
#  2014-05-27   NaN
#  2014-05-28   NaN
#  2014-05-29   NaN
#  2014-05-30   NaN
#  2014-05-31   NaN
#  Name: resid, Length: 1284, dtype: float64)

# %% [markdown]
# ## process the data

# %%
added_features['first_difference'] = added_features.label - added_features.label.shift(1) 
added_features.first_difference.plot()
added_features = added_features.dropna()

result = adfuller(added_features.label)
print(result[1])

result = adfuller(added_features.first_difference)
print(result[1])
# Out:
# 2.9090975219596042e-11
# 1.162194686817638e-22

# %% [markdown]
# ## determine hyperparameters

# %%
plot_acf(added_features.first_difference)
plt.show()

# %%
added_features.first_difference.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# ## training the models

# %%
from pmdarima import auto_arima

# %%
train_size = int(0.8 * len(added_features))

train_df = added_features.iloc[:train_size]
test_df = added_features.iloc[train_size:]

len(train_df), len(test_df)
# Out:
# (1026, 257)

# %%
best_model = auto_arima(train_df['label'], exog=EXOG, axis=1, seasonal=True, stepwise=True, suppress_warnings=True,maxiter=200, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=2238.309, Time=0.79 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=2450.190, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=2281.510, Time=0.11 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=2330.883, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=6899.193, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=2232.828, Time=0.57 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=2283.425, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=2237.325, Time=0.32 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=2232.570, Time=0.81 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=2274.818, Time=0.10 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=2233.957, Time=1.05 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=2232.267, Time=0.94 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=2273.115, Time=0.11 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=2236.342, Time=0.93 sec
#  ARIMA(1,0,5)(0,0,0)[0] intercept   : AIC=2229.975, Time=1.07 sec
#  ARIMA(0,0,5)(0,0,0)[0] intercept   : AIC=2265.639, Time=0.19 sec
#  ARIMA(2,0,5)(0,0,0)[0] intercept   : AIC=2232.883, Time=1.00 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=2267.187, Time=0.37 sec
#
# Best model:  ARIMA(1,0,5)(0,0,0)[0] intercept
# Total fit time: 8.536 seconds

# %%
best_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1027
# Model:               SARIMAX(2, 0, 1)   Log Likelihood               -1111.718
# Date:                Fri, 21 Apr 2023   AIC                           2233.437
# Time:                        16:31:59   BIC                           2258.109
# Sample:                             0   HQIC                          2242.802
#                                - 1027
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.5628      0.191      2.946      0.003       0.188       0.937
# ar.L1          1.0436      0.069     15.062      0.000       0.908       1.179
# ar.L2         -0.1248      0.046     -2.706      0.007      -0.215      -0.034
# ma.L1         -0.7514      0.061    -12.227      0.000      -0.872      -0.631
# sigma2         0.5100      0.018     28.504      0.000       0.475       0.545
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               126.67
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                            -0.46
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
EXOG = train_df.drop(['label', 'id', 'day_id', 'mood','first_difference'], axis=1)
sarima = sm.tsa.statespace.SARIMAX(train_df['label'], exog=EXOG, trend='n', order=(1,0,2), seasonal_order=(1,0,2,30))
model = sarima.fit()
# Out:
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           25     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.59204D+00    |proj g|=  9.55967D-02
#  This problem is unconstrained.
# At iterate    5    f=  1.00906D+00    |proj g|=  1.66154D-01
#
# At iterate   10    f=  9.16433D-01    |proj g|=  1.21549D-01
#
# At iterate   15    f=  8.74360D-01    |proj g|=  6.35576D-02
#
# At iterate   20    f=  8.45704D-01    |proj g|=  2.32794D-02
#
# At iterate   25    f=  8.20962D-01    |proj g|=  1.82833D-02
#
# At iterate   30    f=  8.07790D-01    |proj g|=  1.45931D-02
#
# At iterate   35    f=  8.05852D-01    |proj g|=  8.08503D-03
#
# At iterate   40    f=  8.05096D-01    |proj g|=  2.66617D-03
#
# At iterate   45    f=  8.04790D-01    |proj g|=  1.64151D-03
#
# At iterate   50    f=  8.04719D-01    |proj g|=  1.54697D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    25     50     59      1     0     0   1.547D-03   8.047D-01
#   F =  0.80471933357223813
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              label   No. Observations:                 1026
# Model:             SARIMAX(1, 0, 2)x(1, 0, 2, 30)   Log Likelihood                -825.642
# Date:                            Fri, 21 Apr 2023   AIC                           1701.284
# Time:                                    17:28:09   BIC                           1824.620
# Sample:                                         0   HQIC                          1748.102
#                                            - 1026
# Covariance Type:                              opg
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# circumplex.arousal       0.1898      0.068      2.784      0.005       0.056       0.324
# circumplex.valence       2.0730      0.072     28.626      0.000       1.931       2.215
# activity                 0.1539      0.083      1.854      0.064      -0.009       0.317
# screen                  -0.0901      0.090     -0.996      0.319      -0.267       0.087
# call                     0.0035      0.038      0.090      0.928      -0.072       0.079
# sms                     -0.0489      0.037     -1.329      0.184      -0.121       0.023
# appCat.builtin          -0.0590      0.084     -0.700      0.484      -0.224       0.106
# appCat.communication    -0.1251      0.091     -1.367      0.172      -0.304       0.054
# appCat.entertainment     0.0074      0.099      0.074      0.941      -0.187       0.202
# appCat.finance           0.1767      0.105      1.685      0.092      -0.029       0.382
# appCat.game              0.1984      0.092      2.169      0.030       0.019       0.378
# appCat.office           -0.0657      0.123     -0.536      0.592      -0.306       0.174
# appCat.other             0.0193      0.087      0.223      0.824      -0.150       0.189
# appCat.social           -0.1672      0.076     -2.205      0.027      -0.316      -0.019
# appCat.travel           -0.0214      0.081     -0.263      0.792      -0.181       0.138
# appCat.unknown          -0.0186      0.118     -0.157      0.875      -0.250       0.213
# appCat.utilities        -0.1647      0.089     -1.850      0.064      -0.339       0.010
# appCat.weather           0.1347      0.113      1.194      0.232      -0.086       0.356
# ar.L1                    0.9994      0.001    772.657      0.000       0.997       1.002
# ma.L1                   -0.7548      0.030    -25.182      0.000      -0.814      -0.696
# ma.L2                    0.0035      0.032      0.111      0.912      -0.059       0.066
# ar.S.L30                 0.9897      0.135      7.322      0.000       0.725       1.255
# ma.S.L30                -1.0625      0.153     -6.965      0.000      -1.362      -0.764
# ma.S.L60                 0.0786      0.035      2.238      0.025       0.010       0.148
# sigma2                   0.2907      0.013     21.974      0.000       0.265       0.317
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                17.32
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                            -0.02
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
y_pred = pd.Series(model.forecast(257, exog=test_df.drop(['label', 'id', 'day_id', 'mood', 'first_difference'], axis=1)))
y_pred.index = test_df.label.index
y_true = test_df.label
# Out:
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
np.mean(np.abs(y_pred - test_df.label) / np.abs(test_df.label))
# Out:
# 0.0963878629992714

# %%
mape = np.mean(np.abs(y_pred - y_true) / np.abs(y_true))
mae = np.mean(np.abs(y_pred - y_true))
mpe = np.mean((y_pred - y_true)/y_true)
rmse = np.mean((y_pred - y_true)**2)**.5
corr = np.corrcoef(y_pred, y_true)[0,1]

# %%
mape, mae, mpe, rmse, corr
# Out:
# (0.0963878629992714,
#  0.7233674361432185,
#  -0.07028761976639453,
#  0.8839836249060316,
#  0.52340971745064)

# %% [markdown]
# ## arima on original dataset

# %%
base_normalized = pd.read_csv('pre_processed_dataset/20230415_df_base_normalized.csv', index_col='time')
base_normalized.index = pd.DatetimeIndex(base_normalized.index)
base_normalized
# Out:
#                  id  day_id  mood  label  circumplex.arousal  \
# time
# 2014-03-21  AS14.01    33.0  6.20    6.0            0.707317
# 2014-03-22  AS14.01    34.0  6.40    6.0            0.902439
# 2014-03-23  AS14.01    35.0  6.80    7.0            0.707317
# 2014-03-24  AS14.01    36.0  6.00    6.0            1.000000
# 2014-03-25  AS14.01    37.0  6.75    7.0            0.853659
# ...             ...     ...   ...    ...                 ...
# 2014-05-27  AS14.33   100.0  6.20    6.0            0.500000
# 2014-05-28  AS14.33   101.0  8.20    8.0            0.714286
# 2014-05-29  AS14.33   102.0  7.00    7.0            0.238095
# 2014-05-30  AS14.33   103.0  6.80    7.0            0.428571
# 2014-05-31  AS14.33   104.0  7.00    7.0            0.000000
#
#             circumplex.valence  activity    screen  call  sms  ...  \
# time                                                           ...
# 2014-03-21                 0.2  0.538586  0.523964   1.0  0.0  ...
# 2014-03-22                 0.5  1.000000  0.000000   1.0  1.0  ...
# 2014-03-23                 0.8  0.577584  0.096115   0.0  0.0  ...
# 2014-03-24                 0.0  0.291394  0.144061   1.0  0.0  ...
# 2014-03-25                 0.5  0.378503  0.600205   0.0  1.0  ...
# ...                        ...       ...       ...   ...  ...  ...
# 2014-05-27                 0.5  0.032044  0.163786   1.0  1.0  ...
# 2014-05-28                 0.9  0.297294  0.163890   1.0  1.0  ...
# 2014-05-29                 0.8  0.490686  0.174908   1.0  1.0  ...
# 2014-05-30                 0.1  0.559626  0.107321   1.0  0.0  ...
# 2014-05-31                 0.8  0.559626  0.107321   0.0  0.0  ...
#
#             appCat.entertainment  appCat.finance  appCat.game  appCat.office  \
# time
# 2014-03-21              0.173838        0.031731     0.697244       0.621829
# 2014-03-22              0.141598        0.046043     0.697244       0.414553
# 2014-03-23              0.064503        0.111821     0.697244       0.207276
# 2014-03-24              0.523993        0.022984     0.697244       0.000000
# 2014-03-25              0.077954        0.110321     0.697244       0.046470
# ...                          ...             ...          ...            ...
# 2014-05-27              0.236118        0.000000     0.000000       0.500000
# 2014-05-28              0.163958        0.000000     0.000000       0.000000
# 2014-05-29              0.259683        0.000000     0.000000       0.000000
# 2014-05-30              0.137609        0.000000     0.000000       0.000000
# 2014-05-31              0.137609        0.000000     0.000000       0.000000
#
#             appCat.other  appCat.social  appCat.travel  appCat.unknown  \
# time
# 2014-03-21      0.238221       0.083682       0.471774        0.872530
# 2014-03-22      0.077728       0.034287       0.232857        0.872530
# 2014-03-23      0.058777       0.051490       0.401169        0.872530
# 2014-03-24      0.048269       0.083459       0.569481        0.872530
# 2014-03-25      0.236553       0.075229       0.424449        0.872530
# ...                  ...            ...            ...             ...
# 2014-05-27      0.249610       0.106205       0.053341        0.019081
# 2014-05-28      0.492745       0.363026       0.032430        0.021790
# 2014-05-29      0.053728       0.884805       0.011519        0.024499
# 2014-05-30      0.072780       0.237865       0.503052        0.027207
# 2014-05-31      0.072780       0.237865       0.503052        0.027207
#
#             appCat.utilities  appCat.weather
# time
# 2014-03-21          0.159078             0.0
# 2014-03-22          0.306244             0.0
# 2014-03-23          0.223273             0.0
# 2014-03-24          0.762524             0.0
# 2014-03-25          0.152349             0.0
# ...                      ...             ...
# 2014-05-27          0.842115             0.0
# 2014-05-28          0.172678             0.0
# 2014-05-29          0.000000             0.0
# 2014-05-30          0.684624             0.0
# 2014-05-31          0.684624             0.0
#
# [1290 rows x 22 columns]

# %%
train_size = int(0.8 * len(base_normalized))

train_df = base_normalized.iloc[:train_size]
test_df = base_normalized.iloc[train_size:]

# %%
EXOG = train_df.drop(['label', 'id', 'day_id', 'mood'], axis=1)
sarima = sm.tsa.statespace.SARIMAX(train_df['label'], exog=EXOG, trend='n', order=(1,1,2), seasonal_order=(1,1,2,30))
model = sarima.fit()
# Out:
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           25     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.43488D-01    |proj g|=  5.81426D-01
#  This problem is unconstrained.
# At iterate    5    f=  8.42453D-01    |proj g|=  1.07424D-01
#
# At iterate   10    f=  8.28927D-01    |proj g|=  4.47750D-03
#
# At iterate   15    f=  8.27566D-01    |proj g|=  2.86373D-02
#
# At iterate   20    f=  8.26969D-01    |proj g|=  4.95584D-03
#
# At iterate   25    f=  8.26717D-01    |proj g|=  5.08075D-03
#
# At iterate   30    f=  8.26631D-01    |proj g|=  7.23518D-03
#
# At iterate   35    f=  8.26614D-01    |proj g|=  1.90267D-03
#
# At iterate   40    f=  8.26600D-01    |proj g|=  7.57509D-04
#
# At iterate   45    f=  8.26597D-01    |proj g|=  2.11694D-04
#
# At iterate   50    f=  8.26596D-01    |proj g|=  4.26966D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    25     50     57      1     0     0   4.270D-05   8.266D-01
#   F =  0.82659626158313504
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              label   No. Observations:                 1032
# Model:             SARIMAX(1, 1, 2)x(1, 1, 2, 30)   Log Likelihood                -853.047
# Date:                            Fri, 21 Apr 2023   AIC                           1756.095
# Time:                                    16:53:03   BIC                           1878.814
# Sample:                                         0   HQIC                          1802.734
#                                            - 1032
# Covariance Type:                              opg
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# circumplex.arousal       0.1949      0.071      2.761      0.006       0.057       0.333
# circumplex.valence       2.0515      0.077     26.721      0.000       1.901       2.202
# activity                 0.1028      0.082      1.259      0.208      -0.057       0.263
# screen                  -0.0730      0.093     -0.788      0.431      -0.255       0.109
# call                     0.0177      0.040      0.442      0.658      -0.061       0.096
# sms                     -0.0419      0.037     -1.141      0.254      -0.114       0.030
# appCat.builtin          -0.1037      0.084     -1.241      0.215      -0.267       0.060
# appCat.communication    -0.1057      0.094     -1.123      0.262      -0.290       0.079
# appCat.entertainment    -0.0111      0.096     -0.115      0.908      -0.200       0.178
# appCat.finance           0.1805      0.108      1.667      0.095      -0.032       0.393
# appCat.game              0.1859      0.092      2.016      0.044       0.005       0.367
# appCat.office           -0.0776      0.126     -0.614      0.539      -0.325       0.170
# appCat.other             0.0108      0.089      0.121      0.904      -0.164       0.186
# appCat.social           -0.1843      0.079     -2.345      0.019      -0.338      -0.030
# appCat.travel           -0.0259      0.079     -0.326      0.744      -0.181       0.130
# appCat.unknown          -0.0139      0.124     -0.112      0.910      -0.256       0.228
# appCat.utilities        -0.1756      0.093     -1.880      0.060      -0.359       0.007
# appCat.weather           0.1230      0.126      0.976      0.329      -0.124       0.370
# ar.L1                   -0.4855      1.934     -0.251      0.802      -4.276       3.305
# ma.L1                   -0.2733      1.944     -0.141      0.888      -4.083       3.536
# ma.L2                   -0.3523      1.465     -0.240      0.810      -3.225       2.520
# ar.S.L30                -0.9693      0.177     -5.478      0.000      -1.316      -0.622
# ma.S.L30                -0.0380      4.517     -0.008      0.993      -8.891       8.815
# ma.S.L60                -0.9614      4.370     -0.220      0.826      -9.526       7.603
# sigma2                   0.2892      1.307      0.221      0.825      -2.272       2.851
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                17.78
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.71   Skew:                            -0.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
best_model = auto_arima(train_df['label'], exog=EXOG, axis=1, seasonal=True, stepwise=True, suppress_warnings=True,maxiter=200, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=2246.253, Time=0.67 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=2461.235, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=2290.128, Time=0.11 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=2340.335, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=6939.037, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=2240.602, Time=0.68 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=2292.944, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=2245.154, Time=0.37 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=2240.415, Time=0.65 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=2283.298, Time=0.09 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=2241.916, Time=0.78 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=2240.593, Time=0.96 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=2281.397, Time=0.13 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=2244.334, Time=0.86 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=2270.463, Time=0.08 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0] intercept
# Total fit time: 5.547 seconds

# %%
print(best_model.summary())

# Fit the best SARIMAX model
results = best_model.fit(train_df['label'], exog=EXOG)

# Make predictions on the test set
y_pred = results.predict(n_periods=len(test_df), exog=test_df.drop(['id', 'mood', 'label', 'day_id'], axis=1))

# Calculate mse and mae
mse = (np.square(y_true - y_pred)).mean(axis=ax)

mae = mean_absolute_error(test_df['mood'], y_pred)
print(f'MSE: {mse}')
print(f'MAE: {mae}')
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1032
# Model:               SARIMAX(1, 0, 3)   Log Likelihood               -1114.207
# Date:                Fri, 21 Apr 2023   AIC                           2240.415
# Time:                        16:55:09   BIC                           2270.050
# Sample:                             0   HQIC                          2251.661
#                                - 1032
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.5804      0.199      2.910      0.004       0.190       0.971
# ar.L1          0.9162      0.029     31.819      0.000       0.860       0.973
# ma.L1         -0.6194      0.039    -15.714      0.000      -0.697      -0.542
# ma.L2         -0.0624      0.038     -1.651      0.099      -0.137       0.012
# ma.L3         -0.0532      0.036     -1.460      0.144      -0.125       0.018
# sigma2         0.5072      0.018     28.441      0.000       0.472       0.542
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               127.90
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.73   Skew:                            -0.46
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /home/dariusbarsony/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [150], in <cell line: 10>()
#       7 y_pred = results.predict(n_periods=len(test_df), exog=test_df.drop(['id', 'mood', 'label', 'day_id'], axis=1))
#       9 # Calculate mse and mae
# ---> 10 mse = (np.square(y_true - y_pred)).mean(axis=ax)
#      12 mae = mean_absolute_error(test_df['mood'], y_pred)
#      13 print(f'MSE: {mse}')
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:108, in OpsMixin.__sub__(self, other)
#     106 @unpack_zerodim_and_defer("__sub__")
#     107 def __sub__(self, other):
# --> 108     return self._arith_method(other, operator.sub)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:5638, in Series._arith_method(self, other, op)
#    5637 def _arith_method(self, other, op):
# -> 5638     self, other = ops.align_method_SERIES(self, other)
#    5639     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/__init__.py:167, in align_method_SERIES(left, right, align_asobject)
#     164             left = left.astype(object)
#     165             right = right.astype(object)
# --> 167         left, right = left.align(right, copy=False)
#     169 return left, right
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4514, in Series.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    4496 @doc(
#    4497     NDFrame.align,  # type: ignore[has-type]
#    4498     klass=_shared_doc_kwargs["klass"],
#    (...)
#    4512     broadcast_axis=None,
#    4513 ):
# -> 4514     return super().align(
#    4515         other,
#    4516         join=join,
#    4517         axis=axis,
#    4518         level=level,
#    4519         copy=copy,
#    4520         fill_value=fill_value,
#    4521         method=method,
#    4522         limit=limit,
#    4523         fill_axis=fill_axis,
#    4524         broadcast_axis=broadcast_axis,
#    4525     )
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:8872, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    8860     return self._align_frame(
#    8861         other,
#    8862         join=join,
#    (...)
#    8869         fill_axis=fill_axis,
#    8870     )
#    8871 elif isinstance(other, ABCSeries):
# -> 8872     return self._align_series(
#    8873         other,
#    8874         join=join,
#    8875         axis=axis,
#    8876         level=level,
#    8877         copy=copy,
#    8878         fill_value=fill_value,
#    8879         method=method,
#    8880         limit=limit,
#    8881         fill_axis=fill_axis,
#    8882     )
#    8883 else:  # pragma: no cover
#    8884     raise TypeError(f"unsupported type: {type(other)}")
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:8975, in NDFrame._align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    8973     join_index, lidx, ridx = None, None, None
#    8974 else:
# -> 8975     join_index, lidx, ridx = self.index.join(
#    8976         other.index, how=join, level=level, return_indexers=True
#    8977     )
#    8979 left = self._reindex_indexer(join_index, lidx, copy)
#    8980 right = other._reindex_indexer(join_index, ridx, copy)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:216, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     207 @functools.wraps(meth)
#     208 def join(
#     209     self,
#    (...)
#     214     sort: bool = False,
#     215 ):
# --> 216     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     217     if not return_indexers:
#     218         return join_index
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:4396, in Index.join(self, other, how, level, return_indexers, sort)
#    4394     this = self.astype(dtype, copy=False)
#    4395     other = other.astype(dtype, copy=False)
# -> 4396     return this.join(other, how=how, return_indexers=True)
#    4398 _validate_join_method(how)
#    4400 if not self.is_unique and not other.is_unique:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:216, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     207 @functools.wraps(meth)
#     208 def join(
#     209     self,
#    (...)
#     214     sort: bool = False,
#     215 ):
# --> 216     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     217     if not return_indexers:
#     218         return join_index
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:4408, in Index.join(self, other, how, level, return_indexers, sort)
#    4406             return self._join_monotonic(other, how=how)
#    4407     else:
# -> 4408         return self._join_non_unique(other, how=how)
#    4409 elif (
#    4410     self.is_monotonic
#    4411     and other.is_monotonic
#    (...)
#    4418     # Categorical is monotonic if data are ordered as categories, but join can
#    4419     #  not handle this in case of not lexicographically monotonic GH#38502
#    4420     try:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:4546, in Index._join_non_unique(self, other, how)
#    4543 # We only get here if dtypes match
#    4544 assert self.dtype == other.dtype
# -> 4546 left_idx, right_idx = get_join_indexers(
#    4547     [self._values], [other._values], how=how, sort=True
#    4548 )
#    4549 mask = left_idx == -1
#    4551 join_array = self._values.take(left_idx)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1484, in get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1479 # get left & right join labels and num. of levels at each location
#    1480 mapped = (
#    1481     _factorize_keys(left_keys[n], right_keys[n], sort=sort, how=how)
#    1482     for n in range(len(left_keys))
#    1483 )
# -> 1484 zipped = zip(*mapped)
#    1485 llab, rlab, shape = (list(x) for x in zipped)
#    1487 # get flat i8 keys from label lists
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1481, in <genexpr>(.0)
#    1475 assert len(left_keys) == len(
#    1476     right_keys
#    1477 ), "left_key and right_keys must be the same length"
#    1479 # get left & right join labels and num. of levels at each location
#    1480 mapped = (
# -> 1481     _factorize_keys(left_keys[n], right_keys[n], sort=sort, how=how)
#    1482     for n in range(len(left_keys))
#    1483 )
#    1484 zipped = zip(*mapped)
#    1485 llab, rlab, shape = (list(x) for x in zipped)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:2195, in _factorize_keys(lk, rk, sort, how)
#    2193 if sort:
#    2194     uniques = rizer.uniques.to_array()
# -> 2195     llab, rlab = _sort_labels(uniques, llab, rlab)
#    2197 # NA group
#    2198 lmask = llab == -1
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:2222, in _sort_labels(uniques, left, right)
#    2219 llength = len(left)
#    2220 labels = np.concatenate([left, right])
# -> 2222 _, new_labels = algos.safe_sort(uniques, labels, na_sentinel=-1)
#    2223 assert new_labels.dtype == np.intp
#    2224 new_left, new_right = new_labels[:llength], new_labels[llength:]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py:1732, in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    1726 sorter = None
#    1728 if (
#    1729     not is_extension_array_dtype(values)
#    1730     and lib.infer_dtype(values, skipna=False) == "mixed-integer"
#    1731 ):
# -> 1732     ordered = _sort_mixed(values)
#    1733 else:
#    1734     try:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py:1796, in _sort_mixed(values)
#    1794 """order ints before strings in 1d arrays, safe in py3"""
#    1795 str_pos = np.array([isinstance(x, str) for x in values], dtype=bool)
# -> 1796 nums = np.sort(values[~str_pos])
#    1797 strs = np.sort(values[str_pos])
#    1798 return np.concatenate([nums, np.asarray(strs, dtype=object)])
#
# File <__array_function__ internals>:180, in sort(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:1004, in sort(a, axis, kind, order)
#    1002 else:
#    1003     a = asanyarray(a).copy(order="K")
# -> 1004 a.sort(axis=axis, kind=kind, order=order)
#    1005 return a
#
# TypeError: '<' not supported between instances of 'int' and 'Timestamp'
